# %% [markdown]
# https://platform.openai.com/docs/guides/text-to-speech
#
# ## Voice options
# Experiment with different voices (alloy, echo, fable, onyx, nova, and shimmer) to find one that matches your desired tone and audience. The current voices are optimized for English.

# %%
# !printenv
# Out:
# SHELL=/bin/bash
# WSL2_GUI_APPS_ENABLED=1
# CONDA_EXE=/home/moneebullah25/anaconda3/bin/conda
# _CE_M=
# WSL_DISTRO_NAME=Ubuntu
# WT_SESSION=685968a4-1660-4365-a213-85885f661a62
# OPENAI_API_KEY=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
# NAME=DESKTOP-7G3J62T
# PWD=/mnt/c/Muneeb/Projects/learn-generative-ai/03_chatgpt/10_multimodal_genai/01_text-to-speech
# LOGNAME=moneebullah25
# CONDA_PREFIX=/home/moneebullah25/anaconda3
# JPY_SESSION_NAME=/mnt/c/Muneeb/Projects/learn-generative-ai/03_chatgpt/10_multimodal_genai/01_text-to-speech/01_text-to-speech.ipynb
# _=/usr/bin/printenv
# HOME=/home/moneebullah25
# LANG=C.UTF-8
# WSL_INTEROP=/run/WSL/3848_interop
# LS_COLORS=rs=0:di=01;34:ln=01;36:mh=00:pi=40;33:so=01;35:do=01;35:bd=40;33;01:cd=40;33;01:or=40;31;01:mi=00:su=37;41:sg=30;43:ca=30;41:tw=30;42:ow=34;42:st=37;44:ex=01;32:*.tar=01;31:*.tgz=01;31:*.arc=01;31:*.arj=01;31:*.taz=01;31:*.lha=01;31:*.lz4=01;31:*.lzh=01;31:*.lzma=01;31:*.tlz=01;31:*.txz=01;31:*.tzo=01;31:*.t7z=01;31:*.zip=01;31:*.z=01;31:*.dz=01;31:*.gz=01;31:*.lrz=01;31:*.lz=01;31:*.lzo=01;31:*.xz=01;31:*.zst=01;31:*.tzst=01;31:*.bz2=01;31:*.bz=01;31:*.tbz=01;31:*.tbz2=01;31:*.tz=01;31:*.deb=01;31:*.rpm=01;31:*.jar=01;31:*.war=01;31:*.ear=01;31:*.sar=01;31:*.rar=01;31:*.alz=01;31:*.ace=01;31:*.zoo=01;31:*.cpio=01;31:*.7z=01;31:*.rz=01;31:*.cab=01;31:*.wim=01;31:*.swm=01;31:*.dwm=01;31:*.esd=01;31:*.jpg=01;35:*.jpeg=01;35:*.mjpg=01;35:*.mjpeg=01;35:*.gif=01;35:*.bmp=01;35:*.pbm=01;35:*.pgm=01;35:*.ppm=01;35:*.tga=01;35:*.xbm=01;35:*.xpm=01;35:*.tif=01;35:*.tiff=01;35:*.png=01;35:*.svg=01;35:*.svgz=01;35:*.mng=01;35:*.pcx=01;35:*.mov=01;35:*.mpg=01;35:*.mpeg=01;35:*.m2v=01;35:*.mkv=01;35:*.webm=01;35:*.webp=01;35:*.ogm=01;35:*.mp4=01;35:*.m4v=01;35:*.mp4v=01;35:*.vob=01;35:*.qt=01;35:*.nuv=01;35:*.wmv=01;35:*.asf=01;35:*.rm=01;35:*.rmvb=01;35:*.flc=01;35:*.avi=01;35:*.fli=01;35:*.flv=01;35:*.gl=01;35:*.dl=01;35:*.xcf=01;35:*.xwd=01;35:*.yuv=01;35:*.cgm=01;35:*.emf=01;35:*.ogv=01;35:*.ogx=01;35:*.aac=00;36:*.au=00;36:*.flac=00;36:*.m4a=00;36:*.mid=00;36:*.midi=00;36:*.mka=00;36:*.mp3=00;36:*.mpc=00;36:*.ogg=00;36:*.ra=00;36:*.wav=00;36:*.oga=00;36:*.opus=00;36:*.spx=00;36:*.xspf=00;36:
# WAYLAND_DISPLAY=wayland-0
# FORCE_COLOR=1
# CONDA_PROMPT_MODIFIER=(base)
# PYDEVD_USE_FRAME_EVAL=NO
# CLICOLOR=1
# CLICOLOR_FORCE=1
# JPY_PARENT_PID=4117
# LESSCLOSE=/usr/bin/lesspipe %s %s
# TERM=xterm-color
# _CE_CONDA=
# LESSOPEN=| /usr/bin/lesspipe %s
# USER=moneebullah25
# GIT_PAGER=cat
# CONDA_SHLVL=1
# DISPLAY=:0
# SHLVL=1
# PAGER=cat
# MPLBACKEND=module://matplotlib_inline.backend_inline
# CONDA_PYTHON_EXE=/home/moneebullah25/anaconda3/bin/python
# XDG_RUNTIME_DIR=/mnt/wslg/runtime-dir
# CONDA_DEFAULT_ENV=base
# WSLENV=WT_SESSION:WT_PROFILE_ID:
# XDG_DATA_DIRS=/usr/local/share:/usr/share:/var/lib/snapd/desktop
# PATH=/home/moneebullah25/.local/bin:/home/moneebullah25/anaconda3/bin:/home/moneebullah25/anaconda3/condabin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/usr/lib/wsl/lib:/mnt/c/Program Files/Common Files/Oracle/Java/javapath:/mnt/c/WINDOWS/system32:/mnt/c/WINDOWS:/mnt/c/WINDOWS/System32/Wbem:/mnt/c/WINDOWS/System32/WindowsPowerShell/v1.0:/mnt/c/WINDOWS/System32/OpenSSH:/mnt/c/Program Files/Git/cmd:/mnt/c/Program Files/Microsoft VS Code/bin:/mnt/c/Program Files/Docker/Docker/resources/bin:/mnt/c/Program Files/nodejs:/mnt/c/Users/Dell/AppData/Roaming/Python/Python311/Scripts:/mnt/c/Users/Dell/AppData/Local/Programs/Python/Python311/Scripts:/mnt/c/Users/Dell/AppData/Local/Programs/Python/Python311:/mnt/c/Users/Dell/AppData/Local/Microsoft/WindowsApps:/mnt/c/Users/Dell/AppData/Roaming/npm:/snap/bin
# HOSTTYPE=x86_64
# PULSE_SERVER=unix:/mnt/wslg/PulseServer
# WT_PROFILE_ID={51855cb2-8cce-5362-8f54-464b92b32386}
# OLDPWD=/home/moneebullah25

# %%
from pathlib import Path
from openai import OpenAI

from dotenv import load_dotenv, find_dotenv

_ : bool = load_dotenv(find_dotenv()) # read local .env file

client = OpenAI()

speech_file_path : str = "speech1.mp3"
response = client.audio.speech.create(
  model="tts-1",
  voice="alloy",
  input="Today is a wonderful day to build something people love! Hello"
)

response.stream_to_file(speech_file_path)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[2], line 11
#       8 client = OpenAI()
#      10 speech_file_path : str = "speech1.mp3"
# ---> 11 response = client.audio.speech.create(
#      12   model="tts-1",
#      13   voice="alloy",
#      14   input="Today is a wonderful day to build something people love! Hello"
#      15 )
#      17 response.stream_to_file(speech_file_path)
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/resources/audio/speech.py:73, in Speech.create(self, input, model, voice, response_format, speed, extra_headers, extra_query, extra_body, timeout)
#      30 def create(
#      31     self,
#      32     *,
#    (...)
#      43     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#      44 ) -> HttpxBinaryResponseContent:
#      45     """
#      46     Generates audio from the input text.
#      47
#    (...)
#      71       timeout: Override the client-level default timeout for this request, in seconds
#      72     """
# ---> 73     return self._post(
#      74         "/audio/speech",
#      75         body=maybe_transform(
#      76             {
#      77                 "input": input,
#      78                 "model": model,
#      79                 "voice": voice,
#      80                 "response_format": response_format,
#      81                 "speed": speed,
#      82             },
#      83             speech_create_params.SpeechCreateParams,
#      84         ),
#      85         options=make_request_options(
#      86             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#      87         ),
#      88         cast_to=HttpxBinaryResponseContent,
#      89     )
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:1088, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1074 def post(
#    1075     self,
#    1076     path: str,
#    (...)
#    1083     stream_cls: type[_StreamT] | None = None,
#    1084 ) -> ResponseT | _StreamT:
#    1085     opts = FinalRequestOptions.construct(
#    1086         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1087     )
# -> 1088     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:853, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     844 def request(
#     845     self,
#     846     cast_to: Type[ResponseT],
#    (...)
#     851     stream_cls: type[_StreamT] | None = None,
#     852 ) -> ResponseT | _StreamT:
# --> 853     return self._request(
#     854         cast_to=cast_to,
#     855         options=options,
#     856         stream=stream,
#     857         stream_cls=stream_cls,
#     858         remaining_retries=remaining_retries,
#     859     )
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:916, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     914 if retries > 0 and self._should_retry(err.response):
#     915     err.response.close()
# --> 916     return self._retry_request(
#     917         options,
#     918         cast_to,
#     919         retries,
#     920         err.response.headers,
#     921         stream=stream,
#     922         stream_cls=stream_cls,
#     923     )
#     925 # If the response is streamed then we need to explicitly read the response
#     926 # to completion before attempting to access the response text.
#     927 if not err.response.is_closed:
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:958, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     954 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#     955 # different thread if necessary.
#     956 time.sleep(timeout)
# --> 958 return self._request(
#     959     options=options,
#     960     cast_to=cast_to,
#     961     remaining_retries=remaining,
#     962     stream=stream,
#     963     stream_cls=stream_cls,
#     964 )
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:916, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     914 if retries > 0 and self._should_retry(err.response):
#     915     err.response.close()
# --> 916     return self._retry_request(
#     917         options,
#     918         cast_to,
#     919         retries,
#     920         err.response.headers,
#     921         stream=stream,
#     922         stream_cls=stream_cls,
#     923     )
#     925 # If the response is streamed then we need to explicitly read the response
#     926 # to completion before attempting to access the response text.
#     927 if not err.response.is_closed:
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:958, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     954 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#     955 # different thread if necessary.
#     956 time.sleep(timeout)
# --> 958 return self._request(
#     959     options=options,
#     960     cast_to=cast_to,
#     961     remaining_retries=remaining,
#     962     stream=stream,
#     963     stream_cls=stream_cls,
#     964 )
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:930, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     927     if not err.response.is_closed:
#     928         err.response.read()
# --> 930     raise self._make_status_error_from_response(err.response) from None
#     932 return self._process_response(
#     933     cast_to=cast_to,
#     934     options=options,
#    (...)
#     937     stream_cls=stream_cls,
#     938 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %% [markdown]
# ## Supported languages
#
# The TTS model generally follows the Whisper model in terms of language support. Whisper supports the following languages and performs well despite the current voices being optimized for English:
#
# Afrikaans, Arabic, Armenian, Azerbaijani, Belarusian, Bosnian, Bulgarian, Catalan, Chinese, Croatian, Czech, Danish, Dutch, English, Estonian, Finnish, French, Galician, German, Greek, Hebrew, Hindi, Hungarian, Icelandic, Indonesian, Italian, Japanese, Kannada, Kazakh, Korean, Latvian, Lithuanian, Macedonian, Malay, Marathi, Maori, Nepali, Norwegian, Persian, Polish, Portuguese, Romanian, Russian, Serbian, Slovak, Slovenian, Spanish, Swahili, Swedish, Tagalog, Tamil, Thai, Turkish, Ukrainian, Urdu, Vietnamese, and Welsh.
#
# You can generate spoken audio in these languages by providing the input text in the language of your choice.

# %%
from pathlib import Path
from openai import OpenAI
client = OpenAI()

speech_file_path : str = "urdu.mp3"
response = client.audio.speech.create(
  model="tts-1",
  voice="alloy",
  input="میرا نام محمد قاسم ہے"
)

response.stream_to_file(speech_file_path)

# %% [markdown]
# ## Create file **01_text-to-speech.py**
#
#
# ```
# from pathlib import Path
# from openai import OpenAI
# client = OpenAI()
#
# speech_file_path = Path(__file__).parent / "speech.mp3"
# response = client.audio.speech.create(
#   model="tts-1",
#   voice="alloy",
#   input="Today is a wonderful day to build something people love!"
# )
#
# response.stream_to_file(speech_file_path)
# ```

# %%
# !python 01_text-to-speech.py

# %% [markdown]
# ## Streaming real time audio
# The Speech API provides support for real time audio streaming using chunk transfer encoding. This means that the audio is able to be played before the full file has been generated and made accessible.

# %%
from openai import OpenAI

client = OpenAI()

response = client.audio.speech.create(
    model="tts-1",
    voice="alloy",
    input="Hello world! This is a streaming test.",
)

response.stream_to_file("streaming.mp3")
